# %%
import pandas as pd

from sklearn.feature_extraction.text import TfidfVectorizer
import itertools

from sklearn.metrics.pairwise import cosine_similarity

import pickle

# %%
movies = pd.read_csv('/content/drive/MyDrive/Final_project/Bot_google_colab/movies_df_eddited_1995')

# %%
movies
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 36980   209155          Santosh Subramaniam (2008)
# 36981   209157                           We (2018)
# 36982   209159           Window of the Soul (2001)
# 36983   209163                    Bad Poems (2018)
# 36984   209169                 A Girl Thing (2001)
#
#                                             genres  Year
# 0      Adventure|Animation|Children|Comedy|Fantasy  1995
# 1                       Adventure|Children|Fantasy  1995
# 2                                   Comedy|Romance  1995
# 3                             Comedy|Drama|Romance  1995
# 4                                           Comedy  1995
# ...

# %%
# векторизируем данные
tf = TfidfVectorizer(analyzer=lambda s: (c for i in range(1,3)
                                             for c in itertools.combinations(s.split('|'), r=i)))
tfidf_matrix = tf.fit_transform(movies['genres'])
tfidf_matrix.shape
# Out:
# (36985, 186)

# %%
# считаем близость фильмов
cosine_sim = cosine_similarity(tfidf_matrix)

# %%
cosine_sim_df = pd.DataFrame(cosine_sim, index=movies['movieId'], columns=movies['movieId'])
print('Shape:', cosine_sim_df.shape)
cosine_sim_df
# Out:
# Shape: (36985, 36985)
# movieId    1         2         3         4         5         6         7       \
# movieId
# 1        1.000000  0.619344  0.051965  0.037233  0.123869  0.000000  0.051965
# 2        0.619344  1.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3        0.051965  0.000000  1.000000  0.716498  0.419521  0.000000  1.000000
# 4        0.037233  0.000000  0.716498  1.000000  0.300586  0.000000  0.716498
# 5        0.123869  0.000000  0.419521  0.300586  1.000000  0.000000  0.419521
# ...           ...       ...       ...       ...       ...       ...       ...
# 209155   0.028973  0.000000  0.557546  0.399480  0.233902  0.104698  0.557546
# 209157   0.000000  0.000000  0.000000  0.244853  0.000000  0.000000  0.000000
# 209159   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 209163   0.062481  0.000000  0.211611  0.595914  0.504411  0.000000  0.211611
# 209169   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
# ...

# %%
cosine_sim_df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36985 entries, 1 to 209169
# Columns: 36985 entries, 1 to 209169
# dtypes: float64(36985)
# memory usage: 10.2 GB

# %%
#делаем размер меньше
cosine_sim_df2 = cosine_sim_df[:18000].astype('float16')

# %%
cosine_sim_df3 = cosine_sim_df[18000:].astype('float16')

# %%
cosine_sim_df = pd.concat([cosine_sim_df2, cosine_sim_df3])

# %%
# сохраняем в pickle, чтобы подгрузить в бот
with open('/content/drive/MyDrive/Final_project/Bot_google_colab/cosine_sim_df.pickle', 'wb') as f:
  pickle.dump(cosine_sim_df, f)

# %%
# with open('/content/drive/MyDrive/Final_project/Bot_google_colab/cosine_sim_df.pickle', 'rb') as f:
#   cosine_sim_df=pickle.load(f)
